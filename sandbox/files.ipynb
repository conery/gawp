# %% [markdown]
# ## Operations on Files and Paths

# %%
from pathlib import Path

# %%
! pwd
# Out:
# /Users/conery/Projects/gawp/sandbox

# %%
! ls ../data
# Out:
# PRG-1_herm_g05_sample.xlsx PRG-1_herm_g09_sample.xlsx
# PRG-1_herm_g07_sample.xlsx stages.xlsx

# %%
Path('..').glob('data/PRG-1*')

# %%
list(Path('..').glob('data/PRG-1*'))
# Out:
# [PosixPath('../data/PRG-1_herm_g05_sample.xlsx'),
#  PosixPath('../data/PRG-1_herm_g09_sample.xlsx'),
#  PosixPath('../data/PRG-1_herm_g07_sample.xlsx')]

# %%
[p.resolve() for p in Path('..').glob('data/PRG-1*')]
# Out:
# [PosixPath('/Users/conery/Projects/gawp/data/PRG-1_herm_g05_sample.xlsx'),
#  PosixPath('/Users/conery/Projects/gawp/data/PRG-1_herm_g09_sample.xlsx'),
#  PosixPath('/Users/conery/Projects/gawp/data/PRG-1_herm_g07_sample.xlsx')]

# %%
s = 'data data/PRG-1_herm_g05*'

# %%
lst = []
for part in s.split():
    for f in Path('..').glob(part):
        lst.append(f.resolve())
lst
# Out:
# [PosixPath('/Users/conery/Projects/gawp/data'),
#  PosixPath('/Users/conery/Projects/gawp/data/PRG-1_herm_g05_sample.xlsx')]

# %%
[f.resolve() for part in s.split() for f in Path('..').glob(part)]
# Out:
# [PosixPath('/Users/conery/Projects/gawp/data'),
#  PosixPath('/Users/conery/Projects/gawp/data/PRG-1_herm_g05_sample.xlsx')]

# %%
fn = '../data/PRG-1_herm_g05_sample.xlsx'
p = Path(fn).resolve()

# %%
[p.exists(), p.is_dir(), p.is_file()]
# Out:
# [True, False, True]

# %%
Path('../da').resolve().is_file()
# Out:
# False

# %%
dir(Path('foo.xls'))
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '_copy_from',
#  '_copy_from_file',
#  '_copy_from_symlink',
#  '_delete',
#  '_drv',
#  '_filter_trailing_slash',
#  '_format_parsed_parts',
#  '_from_dir_entry',
#  '_from_parsed_parts',
#  '_from_parsed_string',
#  '_hash',
#  '_info',
#  '_parse_path',
#  '_parse_pattern',
#  '_parts_normcase',
#  '_parts_normcase_cached',
#  '_raw_path',
#  '_raw_paths',
#  '_remove_leading_dot',
#  '_remove_trailing_slash',
#  '_root',
#  '_str',
# ...

# %%
Path('foo.xls').stem
# Out:
# 'foo'

# %%
Path('foo.xls').suffix
# Out:
# '.xls'
